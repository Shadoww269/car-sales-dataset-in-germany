# %% [markdown]
# ## Importing all the required libraries for Data Analysis and Data Cleaning.

# %% [markdown]
# - Importing the data from the csv file and converting it into a dataframe.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\guruc\Desktop\autos.csv",encoding_errors='replace')
df
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3T�RER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          333659 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              351319 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                351044 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             338142 non-null  object
#  14  brand                371528 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# dateCrawled                0
# name                       0
# seller                     0
# offerType                  0
# price                      0
# abtest                     0
# vehicleType            37869
# yearOfRegistration         0
# gearbox                20209
# powerPS                    0
# model                  20484
# kilometer                  0
# monthOfRegistration        0
# fuelType               33386
# brand                      0
# notRepairedDamage      72060
# dateCreated                0
# nrOfPictures               0
# postalCode                 0
# lastSeen                   0
# dtype: int64

# %%
df['vehicleType'].value_counts(dropna=False)
# Out:
# limousine     95894
# kleinwagen    80023
# kombi         67564
# NaN           37869
# bus           30201
# cabrio        22898
# coupe         19015
# suv           14707
# andere         3357
# Name: vehicleType, dtype: int64

# %%
df.head(20)
# Out:
#             dateCrawled                                               name  \
# 0   2016-03-24 11:52:17                                         Golf_3_1.6
# 1   2016-03-24 10:58:45                               A5_Sportback_2.7_Tdi
# 2   2016-03-14 12:52:21                     Jeep_Grand_Cherokee_"Overland"
# 3   2016-03-17 16:54:04                                 GOLF_4_1_4__3T�RER
# 4   2016-03-31 17:25:20                     Skoda_Fabia_1.4_TDI_PD_Classic
# 5   2016-04-04 17:36:23  BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...
# 6   2016-04-01 20:48:51                        Peugeot_206_CC_110_Platinum
# 7   2016-03-21 18:54:38                       VW_Derby_Bj_80__Scheunenfund
# 8   2016-04-04 23:42:13               Ford_C___Max_Titanium_1_0_L_EcoBoost
# 9   2016-03-17 10:53:50  VW_Golf_4_5_tuerig_zu_verkaufen_mit_Anhaengerk...
# 10  2016-03-26 19:54:18                                  Mazda_3_1.6_Sport
# ...

# %%
df.nrOfPictures.value_counts()
# Out:
# 0    371528
# Name: nrOfPictures, dtype: int64

# %%
df.isnull().sum()
# Out:
# dateCrawled                0
# name                       0
# seller                     0
# offerType                  0
# price                      0
# abtest                     0
# vehicleType            37869
# yearOfRegistration         0
# gearbox                20209
# powerPS                    0
# model                  20484
# kilometer                  0
# monthOfRegistration        0
# fuelType               33386
# brand                      0
# notRepairedDamage      72060
# dateCreated                0
# nrOfPictures               0
# postalCode                 0
# lastSeen                   0
# dtype: int64

# %% [markdown]
# ### Filling the null values in the columns with a value called as 'Not Mentioned'.

# %%
df1 = df.fillna('Not Mentioned')
df1
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3T�RER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest    vehicleType  yearOfRegistration  \
# ...

# %%
df1.isnull().sum()
# Out:
# dateCrawled            0
# name                   0
# seller                 0
# offerType              0
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# model                  0
# kilometer              0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# dateCreated            0
# nrOfPictures           0
# postalCode             0
# lastSeen               0
# dtype: int64

# %%
df1.yearOfRegistration.unique()
# Out:
# array([1993, 2011, 2004, 2001, 2008, 1995, 1980, 2014, 1998, 2005, 1910,
#        2016, 2007, 2009, 2002, 2018, 1997, 1990, 2017, 1981, 2003, 1994,
#        1991, 1984, 2006, 1999, 2012, 2010, 2000, 1992, 2013, 1996, 1985,
#        1989, 2015, 1968, 1982, 1976, 1983, 1959, 1973, 1111, 1969, 1971,
#        1987, 1986, 1988, 1967, 1970, 1965, 1945, 1925, 1974, 1979, 1955,
#        1978, 1972, 1977, 1961, 1963, 1964, 1960, 1966, 1975, 1937, 1936,
#        5000, 1954, 1958, 9999, 1956, 3200, 1000, 1933, 1941, 1962, 8888,
#        1500, 2200, 4100, 1929, 1951, 1957, 1940, 3000, 2066, 1949, 2019,
#        1800, 1953, 1935, 1234, 8000, 5300, 9000, 2900, 6000, 5900, 5911,
#        1400, 1950, 4000, 1948, 1952, 1200, 8500, 1932, 1255, 1927, 1923,
#        1931, 3700, 3800, 4800, 1942, 7000, 1911, 6500, 2290, 2500, 1930,
#        1001, 6200, 9450, 1944, 1943, 1947, 1934, 1938, 1688, 2800, 1253,
#        1928, 7500, 1919, 5555, 7777, 5600, 1600, 1939, 2222, 1039, 9996,
# ...

# %%
y = df1.loc[df1["yearOfRegistration"]>2023,['yearOfRegistration']]

# %%
df1.loc[df1["yearOfRegistration"]>2023,['yearOfRegistration']].replace(np.nan)
# Out:
#         yearOfRegistration
# 13576                 5000
# 15894                 9999
# 16657                 3200
# 18121                 9999
# 18196                 8888
# ...                    ...
# 351235                4000
# 352029                7500
# 355280                3000
# 357075                3500
# 358386                3000
#
# [114 rows x 1 columns]

# %%
df1.loc[df1['yearOfRegistration']>2023,['yearOfRegistration']]
# Out:
#         yearOfRegistration
# 13576                 5000
# 15894                 9999
# 16657                 3200
# 18121                 9999
# 18196                 8888
# ...                    ...
# 351235                4000
# 352029                7500
# 355280                3000
# 357075                3500
# 358386                3000
#
# [114 rows x 1 columns]

# %%
df2 = df1
df2
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3T�RER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest    vehicleType  yearOfRegistration  \
# ...

# %%
df2.loc[df2["yearOfRegistration"]>2023,['yearOfRegistration']]
# Out:
#         yearOfRegistration
# 13576                 5000
# 15894                 9999
# 16657                 3200
# 18121                 9999
# 18196                 8888
# ...                    ...
# 351235                4000
# 352029                7500
# 355280                3000
# 357075                3500
# 358386                3000
#
# [114 rows x 1 columns]

# %%
df3 = df2.yearOfRegistration.astype('object')

# %%
df2.loc[df2["yearOfRegistration"]>2023,['yearOfRegistration']]
# Out:
#         yearOfRegistration
# 13576                 5000
# 15894                 9999
# 16657                 3200
# 18121                 9999
# 18196                 8888
# ...                    ...
# 351235                4000
# 352029                7500
# 355280                3000
# 357075                3500
# 358386                3000
#
# [114 rows x 1 columns]

# %%
df2['yearOfRegistration'].where(((df2['yearOfRegistration']<2023) & (df2['yearOfRegistration']>1900)),df["yearOfRegistration"].mode()[0],inplace=True)

# %%
df2.yearOfRegistration = df2.yearOfRegistration.astype(int)

# %%
df2['yearOfRegistration'].value_counts()
# Out:
# 2000    24733
# 1999    22767
# 2005    22316
# 2006    20230
# 2001    20218
#         ...
# 1911        1
# 1919        1
# 1915        1
# 1920        1
# 1925        1
# Name: yearOfRegistration, Length: 100, dtype: int64

# %%
df2
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3T�RER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest    vehicleType  yearOfRegistration  \
# ...

# %%
df2['monthOfRegistration'].value_counts()
# Out:
# 0     37675
# 3     36170
# 6     33167
# 4     30918
# 5     30631
# 7     28958
# 10    27337
# 11    25489
# 12    25380
# 9     25074
# 1     24561
# 8     23765
# 2     22403
# Name: monthOfRegistration, dtype: int64

# %%
df3 = df2.copy()
df3
# Out:
#                 dateCrawled                                          name  \
# 0       2016-03-24 11:52:17                                    Golf_3_1.6
# 1       2016-03-24 10:58:45                          A5_Sportback_2.7_Tdi
# 2       2016-03-14 12:52:21                Jeep_Grand_Cherokee_"Overland"
# 3       2016-03-17 16:54:04                            GOLF_4_1_4__3T�RER
# 4       2016-03-31 17:25:20                Skoda_Fabia_1.4_TDI_PD_Classic
# ...                     ...                                           ...
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest    vehicleType  yearOfRegistration  \
# ...

# %%
df3.drop(df[df['monthOfRegistration']==0].index,inplace=True)

# %%
df3
# Out:
#                 dateCrawled  \
# 1       2016-03-24 10:58:45
# 2       2016-03-14 12:52:21
# 3       2016-03-17 16:54:04
# 4       2016-03-31 17:25:20
# 5       2016-04-04 17:36:23
# ...                     ...
# 371523  2016-03-14 17:48:27
# 371524  2016-03-05 19:56:21
# 371525  2016-03-19 18:57:12
# 371526  2016-03-20 19:41:08
# 371527  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 1                                    A5_Sportback_2.7_Tdi  privat   Angebot
# 2                          Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3                                      GOLF_4_1_4__3T�RER  privat   Angebot
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# ...                                                   ...     ...       ...
# 371523                         Suche_t4___vito_ab_6_sitze  privat   Angebot
# ...

# %%
df3.reset_index(drop=True,inplace=True)

# %%
df3
# Out:
#                 dateCrawled  \
# 0       2016-03-24 10:58:45
# 1       2016-03-14 12:52:21
# 2       2016-03-17 16:54:04
# 3       2016-03-31 17:25:20
# 4       2016-04-04 17:36:23
# ...                     ...
# 333848  2016-03-14 17:48:27
# 333849  2016-03-05 19:56:21
# 333850  2016-03-19 18:57:12
# 333851  2016-03-20 19:41:08
# 333852  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 0                                    A5_Sportback_2.7_Tdi  privat   Angebot
# 1                          Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 2                                      GOLF_4_1_4__3T�RER  privat   Angebot
# 3                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 4       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# ...                                                   ...     ...       ...
# 333848                         Suche_t4___vito_ab_6_sitze  privat   Angebot
# ...

# %% [markdown]
# ### 2. Can you tell me the Distribution of Vehicles based on Year of Registration with the help of a plot

# %%
plt.figure(figsize=(15,15))
sns.set_theme(palette='deep',font='Times New Roman')
sns.displot(data=df3,x='yearOfRegistration',hue='vehicleType',height=6)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.set_theme(palette='deep',font='Times New Roman')
sns.kdeplot(data=df3,x='yearOfRegistration',hue='vehicleType')
plt.show()

# %%
df3.groupby(['vehicleType'])['price'].mean()
# Out:
# vehicleType
# Not Mentioned      8727.600193
# andere           805033.432116
# bus                7179.557783
# cabrio            11060.605692
# coupe             22029.703668
# kleinwagen         4416.571360
# kombi              7784.769422
# limousine         11674.207516
# suv               13490.937203
# Name: price, dtype: float64

# %% [markdown]
# ### 3. Create a plot based on the Variation of the price range by the vehicle type.

# %%
filtered_df=df3[df3['vehicleType'] != 'andere']

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=filtered_df,x='vehicleType',y='price',ci=None)
# Out:
# <AxesSubplot:xlabel='vehicleType', ylabel='price'>

# %% [markdown]
# ### 4. Find out Total count of vehicles by type available on ebay for sale.As well as create a visualization for the client

# %%
df3.vehicleType.value_counts()
# Out:
# limousine        90157
# kleinwagen       73185
# kombi            62816
# bus              28737
# Not Mentioned    22816
# cabrio           21643
# coupe            17585
# suv              14093
# andere            2821
# Name: vehicleType, dtype: int64

# %%
sns.countplot(data=df3,x='vehicleType')
plt.title('TotalCount of Vehicles')
plt.xticks(rotation='45')
plt.show()

# %%
import scipy as s
import scipy.stats as ss

# %% [markdown]
# ### 5.  Is there any relationship between dollar_price and kilometer?
# (Explain with appropriate analysis)

# %%
sns.scatterplot(data=filtered_df,y='price',x='kilometer')
# Out:
# <AxesSubplot:xlabel='kilometer', ylabel='price'>

# %%
df3[['price','kilometer']].corr(method='pearson')
# Out:
#               price  kilometer
# price      1.000000  -0.000252
# kilometer -0.000252   1.000000

# %%
df3.to_csv('Clean_dataframe.csv')
